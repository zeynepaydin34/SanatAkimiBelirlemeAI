# %%
import os
import imagehash
from PIL import Image
from collections import defaultdict

# Görüntünün pHash değerini hesaplama
def calculate_phash(image_path):
    image = Image.open(image_path)
    return imagehash.phash(image)

# Aynı olan görüntüleri bulma ve silme
def find_and_remove_duplicates(base_folder):
    hash_dict = defaultdict(list)
    
    # Tüm klasörleri ve resim dosyalarını tarama
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(root, file)
                image_hash = calculate_phash(file_path)
                hash_dict[image_hash].append(file_path)
    
    # Aynı olan görüntüleri bulma ve birini silme
    deleted_files = []
    for image_hash, paths in hash_dict.items():
        if len(paths) > 1:
            print(f"Aynı görüntüler: {paths}")
            # İlk resmi tutup diğerlerini silme
            for duplicate_image in paths[1:]:
                os.remove(duplicate_image)  # Duplicate olan resmi silme
                deleted_files.append(duplicate_image)
                print(f"Silinen dosya: {duplicate_image}")
    
    return deleted_files

base_folder = r"E:\YazLab Proje\Realism"  
deleted_images = find_and_remove_duplicates(base_folder)

# Silinen resimlerin listesi ve sayısı
print("\nSilinen Görüntüler:")
for image in deleted_images:
    print(image)

print(f"\nToplam Silinen Resim Sayısı: {len(deleted_images)}")
# Out:
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_109.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de129.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de129.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_229.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_271.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_271.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_237.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de148.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de148.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_26.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de120.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de120.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_27.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de23.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de23.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_292.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_522.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_522.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_360.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_828.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_828.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_397.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_581.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_581.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_518.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de443.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de443.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_537.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de567.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de567.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_735.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de136.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de136.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de131.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de471.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de471.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de171.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de260.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de260.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de190.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de378.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de378.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de197.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_2691.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_2691.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de270.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_972.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_972.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de314.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_3038.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_3038.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de319.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de465.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de465.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de32.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_1318.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_1318.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de456.jpg', 'E:\\YazLab Proje\\Realism\\realism_pin_de602.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_pin_de602.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de48.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_16.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_16.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de532.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_431.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_431.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de596.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_2002.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_2002.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_pin_de81.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_689.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_689.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_1121.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_628.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_628.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_1395.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_1399.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_1399.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_1594.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_1615.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_1615.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_1705.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_1709.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_1709.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_2000.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_2170.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_2170.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_2669.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_2798.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_2798.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_2679.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_2803.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_2803.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_3139.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_665.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_665.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_3256.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_3410.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_3410.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Realism\\realism_wikiart_3258.jpg', 'E:\\YazLab Proje\\Realism\\realism_wikiart_3414.jpg']
# Silinen dosya: E:\YazLab Proje\Realism\realism_wikiart_3414.jpg
#
# Silinen Görüntüler:
# E:\YazLab Proje\Realism\realism_pin_de129.jpg
# E:\YazLab Proje\Realism\realism_pin_271.jpg
# E:\YazLab Proje\Realism\realism_pin_de148.jpg
# E:\YazLab Proje\Realism\realism_pin_de120.jpg
# E:\YazLab Proje\Realism\realism_pin_de23.jpg
# E:\YazLab Proje\Realism\realism_pin_522.jpg
# E:\YazLab Proje\Realism\realism_wikiart_828.jpg
# E:\YazLab Proje\Realism\realism_pin_581.jpg
# E:\YazLab Proje\Realism\realism_pin_de443.jpg
# E:\YazLab Proje\Realism\realism_pin_de567.jpg
# E:\YazLab Proje\Realism\realism_pin_de136.jpg
# E:\YazLab Proje\Realism\realism_pin_de471.jpg
# E:\YazLab Proje\Realism\realism_pin_de260.jpg
# E:\YazLab Proje\Realism\realism_pin_de378.jpg
# E:\YazLab Proje\Realism\realism_wikiart_2691.jpg
# E:\YazLab Proje\Realism\realism_wikiart_972.jpg
# E:\YazLab Proje\Realism\realism_wikiart_3038.jpg
# E:\YazLab Proje\Realism\realism_pin_de465.jpg
# E:\YazLab Proje\Realism\realism_wikiart_1318.jpg
# E:\YazLab Proje\Realism\realism_pin_de602.jpg
# E:\YazLab Proje\Realism\realism_wikiart_16.jpg
# E:\YazLab Proje\Realism\realism_wikiart_431.jpg
# E:\YazLab Proje\Realism\realism_wikiart_2002.jpg
# E:\YazLab Proje\Realism\realism_wikiart_689.jpg
# E:\YazLab Proje\Realism\realism_wikiart_628.jpg
# E:\YazLab Proje\Realism\realism_wikiart_1399.jpg
# E:\YazLab Proje\Realism\realism_wikiart_1615.jpg
# E:\YazLab Proje\Realism\realism_wikiart_1709.jpg
# E:\YazLab Proje\Realism\realism_wikiart_2170.jpg
# E:\YazLab Proje\Realism\realism_wikiart_2798.jpg
# E:\YazLab Proje\Realism\realism_wikiart_2803.jpg
# E:\YazLab Proje\Realism\realism_wikiart_665.jpg
# E:\YazLab Proje\Realism\realism_wikiart_3410.jpg
# E:\YazLab Proje\Realism\realism_wikiart_3414.jpg
#
# Toplam Silinen Resim Sayısı: 34
