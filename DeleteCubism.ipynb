# %%
import os
import imagehash
from PIL import Image
from collections import defaultdict

# Görüntünün pHash değerini hesaplama
def calculate_phash(image_path):
    image = Image.open(image_path)
    return imagehash.phash(image)

# Aynı olan görüntüleri bulma ve silme
def find_and_remove_duplicates(base_folder):
    hash_dict = defaultdict(list)
    
    # Tüm klasörleri ve görüntü dosyalarını tarama
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(root, file)
                image_hash = calculate_phash(file_path)
                hash_dict[image_hash].append(file_path)
    
    # Aynı olan görüntüleri bulma ve birini silme
    deleted_files = []
    for image_hash, paths in hash_dict.items():
        if len(paths) > 1:
            print(f"Aynı görüntüler: {paths}")
            # İlk resmi tutup diğerlerini silme
            for duplicate_image in paths[1:]:
                os.remove(duplicate_image)  # Duplicate olan resmi silme
                deleted_files.append(duplicate_image)
                print(f"Silinen dosya: {duplicate_image}")
    
    return deleted_files

base_folder = r"E:\YazLab Proje\Cubism"  
deleted_images = find_and_remove_duplicates(base_folder)

# Silinen resimlerin listesi ve sayısı
print("\nSilinen Görüntüler:")
for image in deleted_images:
    print(image)

print(f"\nToplam Silinen Resim Sayısı: {len(deleted_images)}")
# Out:
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_art_398.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_55.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_55.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_dev_1097.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_dev_824.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_dev_824.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_dev_1205.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_dev_922.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_dev_922.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_129.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_83.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_83.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_135.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_wikiart_1660.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_wikiart_1660.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_163.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_194.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_194.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_179.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_435.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_435.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_183.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_250.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_250.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_204.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_532.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_532.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_277.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_433.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_433.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_29.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_76.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_76.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_36.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_wikiart_544.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_wikiart_544.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_362.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_400.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_400.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_415.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_pin_494.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_pin_494.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_pin_90.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_wikiart_283.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_wikiart_283.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_wikiart_1198.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_wikiart_1199.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_wikiart_1199.jpg
# Aynı görüntüler: ['E:\\YazLab Proje\\Cubism\\cubism_wikiart_1717.jpg', 'E:\\YazLab Proje\\Cubism\\cubism_wikiart_1950.jpg']
# Silinen dosya: E:\YazLab Proje\Cubism\cubism_wikiart_1950.jpg
#
# Silinen Görüntüler:
# E:\YazLab Proje\Cubism\cubism_pin_55.jpg
# E:\YazLab Proje\Cubism\cubism_dev_824.jpg
# E:\YazLab Proje\Cubism\cubism_dev_922.jpg
# E:\YazLab Proje\Cubism\cubism_pin_83.jpg
# E:\YazLab Proje\Cubism\cubism_wikiart_1660.jpg
# E:\YazLab Proje\Cubism\cubism_pin_194.jpg
# E:\YazLab Proje\Cubism\cubism_pin_435.jpg
# E:\YazLab Proje\Cubism\cubism_pin_250.jpg
# E:\YazLab Proje\Cubism\cubism_pin_532.jpg
# E:\YazLab Proje\Cubism\cubism_pin_433.jpg
# E:\YazLab Proje\Cubism\cubism_pin_76.jpg
# E:\YazLab Proje\Cubism\cubism_wikiart_544.jpg
# E:\YazLab Proje\Cubism\cubism_pin_400.jpg
# E:\YazLab Proje\Cubism\cubism_pin_494.jpg
# E:\YazLab Proje\Cubism\cubism_wikiart_283.jpg
# E:\YazLab Proje\Cubism\cubism_wikiart_1199.jpg
# E:\YazLab Proje\Cubism\cubism_wikiart_1950.jpg
#
# Toplam Silinen Resim Sayısı: 17
